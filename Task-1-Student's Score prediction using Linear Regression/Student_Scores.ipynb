# %% [markdown]
# #### Avinash Singh :  DataScience and Business Analytics Intern @ The Spark Foundation

# %% [markdown]
# #### Problem Statement:
#
# ![ss.png](attachment:ss.png)

# %% [markdown]
# #### Algorithm Type : Supervised
# #### Algorithm  used : Linear Regression

# %%
#Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm 
from sklearn import metrics
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
#Read the dataset stored in the .csv file
df=pd.read_csv("student_scores.csv")

# %%
#View Top 5 records
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
#Dataset Description
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#Checking null values
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
#Plot the data
plt.scatter(df['Hours'],df['Scores'], label= "stars", color= "red",  
            marker= "o", s=30)
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title("Data Distribution")
plt.show()

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Hours'}>,
#         <AxesSubplot:title={'center':'Scores'}>]], dtype=object)

# %%
#Plotting a histogram 
range = (0, 100)        #Minimum score to Maximum Score
bins=10
plt.hist(df['Scores'], bins, range, color = 'orange', 
        histtype = 'barstacked', rwidth=0.8) 
  
# x-axis label 
plt.xlabel('Scores') 
# frequency label 
plt.ylabel('No.of Students') 
# plot title 
plt.title('Score Board') 
  
# function to show the plot 
plt.show()

# %%
#Plotting a histogram 
range = (0, 12)       
bins=10
plt.hist(df['Hours'], bins, range, color = 'Blue', 
        histtype = 'barstacked', rwidth=0.8) 
  
# x-axis label 
plt.xlabel('Hours') 
# frequency label 
plt.ylabel('No.of Students') 
# plot title 
plt.title('Study Hours') 
  
# function to show the plot 
plt.show()

# %%
# Importing libraries 
import pandas as pd 
import numpy as np 
from sklearn import preprocessing 
import matplotlib 
import matplotlib.pyplot as plt 

matplotlib.style.use('fivethirtyeight') 

# data 
x = df
np.random.normal 


scaler = preprocessing.StandardScaler() 
standard_df = scaler.fit_transform(x) 
standard_df = pd.DataFrame(standard_df, columns =['Hours','Scores']) 

scaler = preprocessing.MinMaxScaler() 
minmax_df = scaler.fit_transform(x) 
minmax_df = pd.DataFrame(minmax_df, columns =['Hours','Scores']) 

fig, (ax1, ax3, ax4) = plt.subplots(ncols = 3, figsize =(20, 5)) 

ax1.set_title('Before Scaling') 
sns.kdeplot(df['Hours'], ax = ax1, color ='r') 
sns.kdeplot(df['Scores'], ax = ax1, color ='b') 

ax3.set_title('After Standard Scaling') 
sns.kdeplot(standard_df['Hours'], ax = ax3, color ='black') 
sns.kdeplot(standard_df['Scores'], ax = ax3, color ='g') 

ax4.set_title('After Min-Max Scaling') 
sns.kdeplot(minmax_df['Hours'], ax = ax4, color ='black') 
sns.kdeplot(minmax_df['Scores'], ax = ax4, color ='g') 
plt.show()

# %%
#Prepraing the Training and Test Data
X=minmax_df[['Hours']]
y=minmax_df[['Scores']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %% [markdown]
# #### Building the Linear Regression Model

# %%
regr = LinearRegression() 
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Testing the Test data on the Model

# %%
print(regr.score(X_test, y_test))
# Out:
# 0.960192581830204

# %%
y_pred = regr.predict(X_test) 
plt.scatter(X_train,y_train, color='black')
plt.scatter(X_test, y_test, color ='red') 
plt.plot(X_test, y_pred, color ='orange') 
  
plt.show()

# %%
# model evaluation for testing set

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 0.056860731311266545
# MSE is 0.003765085587052501
# R2 score is 0.960192581830204

# %%
input_hrs=[[(9.25 - 1.1)/(9.2-1.1)]]
score_pred=regr.predict(input_hrs)
#Actual value is :
print("Predicted Score  :",(score_pred*78)+17) #Rescaling it back to the Original Scale
# Out:
# Predicted Score  : [[92.47289852]]

# %% [markdown]
# ### Conclusion

# %% [raw]
# '''
# Since the size of the dataset is too small so it is not a good idea to rely on the accurracy of the model.
# We can also use some other Algorithms to improve performance of our model .
# However as per the results obtained:
#
# The MAE (Mean Absolute Error) of 0.5517 is a good value.
#
# MSE is used to check how close estimates or forecasts are to actual values.
# Lower the MSE, the closer is forecast to actual.
# This is used as a model evaluation measure for regression models
# and the lower value indicates a better fit. Hence, MSE of 0.003 indicates a good fit.
#
# The most common interpretation of r-squared is how well the regression model fits the observed data.
# An r-squared of 97.06% reveals that 97.06% of the data fit the regression model.
# Generally, a higher r-squared indicates a better fit for the model.
#
# '''

# %% [markdown]
# Youtube Link : https://youtu.be/Y0o7arJhpbA
